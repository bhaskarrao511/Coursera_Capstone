# %% [markdown]
# ## Exploring and clustering neighborhoods in Toronto - IBM data science certification

# %% [markdown]
# ### Part 1 - building a dataframe of the postal code of each neighborhood along with the borough name and neighborhood name

# %%
# IMPORTING LIBRARIES
import requests
from bs4 import BeautifulSoup
from csv import writer
import pandas as pd
import numpy as np

# %%
# SETTING UP BEAUTIFULL SOUP

response = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M') # REQUESTING URL
soup = BeautifulSoup(response.text, "lxml")
wiki_table = soup.find("table",{ "class" : "wikitable sortable" } ) #LOCATING WIKIPEDIA TABLE
table_data = wiki_table.tbody.find_all("tr") # LOCATING THE HEADER

# %%
#lOCATING AND SAVING Wikipedia COLUMN HEADERS
column = [x.text.strip() for x in table_data[0].find_all("th")]
column # COLUMN HEADERS
# Out:
# ['Postcode', 'Borough', 'Neighbourhood']

# %%
# FINDING AND SAVING EACH ELEMENT OF TABLE AS PER COLUMNS AND ROWS
data_table = pd.DataFrame(columns = column)
rows = []
for i in range(1,len(table_data)-1):
    rows = [x.text.strip() for x in table_data[i].find_all("td")]
    data_table.loc[i] = rows

data_table.head() # SAMPLE OF TABLE
# Out:
#   Postcode           Borough     Neighbourhood
# 1      M1A      Not assigned      Not assigned
# 2      M2A      Not assigned      Not assigned
# 3      M3A        North York         Parkwoods
# 4      M4A        North York  Victoria Village
# 5      M5A  Downtown Toronto      Harbourfront

# %%
# LOOKING AT UN-ASSIGNED BOROUGH AND NEIGHBOURHOOD 
data_table.reset_index(inplace = True)
data_table = data_table[data_table["Borough"] != "Not assigned"]
data_table["Neighbourhood"][data_table["Neighbourhood"] == "Not assigned"] = data_table["Borough"]

# %%
# POSTCODES WITH MULTIPLE NEIGHBOUR HOOD

aggre_postcode = data_table.pivot_table(index = "Postcode", values = "Neighbourhood", aggfunc = "count")
postcode_mult = aggre_postcode.index[aggre_postcode["Neighbourhood"] > 1]
postcode_mult
# Out:
# Index(['M1B', 'M1C', 'M1E', 'M1K', 'M1L', 'M1M', 'M1N', 'M1P', 'M1R', 'M1T',
#        'M1V', 'M2J', 'M2L', 'M2M', 'M3C', 'M3H', 'M3J', 'M3K', 'M4B', 'M4K',
#        'M4L', 'M4T', 'M4V', 'M4X', 'M5B', 'M5H', 'M5J', 'M5K', 'M5L', 'M5M',
#        'M5P', 'M5R', 'M5S', 'M5T', 'M5V', 'M5X', 'M6A', 'M6H', 'M6J', 'M6K',
#        'M6L', 'M6M', 'M6N', 'M6P', 'M6R', 'M6S', 'M8V', 'M8W', 'M8X', 'M8Y',
#        'M8Z', 'M9B', 'M9C', 'M9M', 'M9R', 'M9V'],
#       dtype='object', name='Postcode')

# %%
# POSTCODES WITH single NEIGHBOUR HOOD

postcode_single = aggre_postcode.index[aggre_postcode["Neighbourhood"] == 1]
postcode_single
# Out:
# Index(['M1G', 'M1H', 'M1J', 'M1S', 'M1W', 'M1X', 'M2H', 'M2K', 'M2N', 'M2P',
#        'M2R', 'M3A', 'M3B', 'M3L', 'M3M', 'M3N', 'M4A', 'M4C', 'M4E', 'M4G',
#        'M4H', 'M4J', 'M4M', 'M4N', 'M4P', 'M4R', 'M4S', 'M4W', 'M4Y', 'M5A',
#        'M5C', 'M5E', 'M5G', 'M5N', 'M5W', 'M6B', 'M6C', 'M6E', 'M6G', 'M7A',
#        'M7R', 'M7Y', 'M9A', 'M9L', 'M9N', 'M9P', 'M9W'],
#       dtype='object', name='Postcode')

# %%
# TABLE WITH MULTIPLE NEIGHBOURHOOD FOR SINGLE postocde
tab1 = data_table.loc[data_table.Postcode.isin(postcode_mult),:].sort_values(by='Postcode').reset_index(drop=True)
tab1
# Out:
#      index Postcode      Borough             Neighbourhood
# 0       11      M1B  Scarborough                     Rouge
# 1       12      M1B  Scarborough                   Malvern
# 2       29      M1C  Scarborough                Port Union
# 3       28      M1C  Scarborough                Rouge Hill
# 4       27      M1C  Scarborough            Highland Creek
# 5       42      M1E  Scarborough                 Guildwood
# 6       44      M1E  Scarborough                 West Hill
# 7       43      M1E  Scarborough               Morningside
# 8       91      M1K  Scarborough      East Birchmount Park
# 9       92      M1K  Scarborough                   Ionview
# 10      93      M1K  Scarborough              Kennedy Park
# 11     107      M1L  Scarborough                  Clairlea
# 12     108      M1L  Scarborough               Golden Mile
# 13     109      M1L  Scarborough                  Oakridge
# 14     125      M1M  Scarborough  Scarborough Village West
# 15     124      M1M  Scarborough                 Cliffside
# 16     123      M1M  Scarborough                Cliffcrest
# 17     141      M1N  Scarborough            Cliffside West
# 18     140      M1N  Scarborough               Birch Cliff
# 19     151      M1P  Scarborough               Dorset Park
# 20     152      M1P  Scarborough   Scarborough Town Centre
# 21     153      M1P  Scarborough           Wexford Heights
# 22     165      M1R  Scarborough                   Wexford
# 23     164      M1R  Scarborough                  Maryvale
# 24     193      M1T  Scarborough             Tam O'Shanter
# 25     192      M1T  Scarborough                  Sullivan
# 26     191      M1T  Scarborough            Clarks Corners
# 27     205      M1V  Scarborough           Agincourt North
# 28     208      M1V  Scarborough              Steeles East
# 29     206      M1V  Scarborough           L'Amoreaux East
# ..     ...      ...          ...                       ...
# 133    271      M8Y    Etobicoke        The Queensway East
# 134    267      M8Y    Etobicoke          King's Mill Park
# 135    284      M8Z    Etobicoke        The Queensway West
# 136    282      M8Z    Etobicoke  Kingsway Park South West
# 137    283      M8Z    Etobicoke                 Mimico NW
# 138    286      M8Z    Etobicoke            South of Bloor
# 139    285      M8Z    Etobicoke     Royal York South West
# 140     25      M9B    Etobicoke          Princess Gardens
# 141     24      M9B    Etobicoke              Martin Grove
# 142     23      M9B    Etobicoke                 Islington
# 143     22      M9B    Etobicoke                Cloverdale
# 144     26      M9B    Etobicoke           West Deane Park
# 145     41      M9C    Etobicoke         Old Burnhamthorpe
# 146     40      M9C    Etobicoke             Markland Wood
# 147     39      M9C    Etobicoke                  Eringate
# 148     38      M9C    Etobicoke         Bloordale Gardens
# 149    138      M9M   North York                     Emery
# 150    139      M9M   North York                 Humberlea
# 151    179      M9R    Etobicoke              St. Phillips
# 152    178      M9R    Etobicoke          Richview Gardens
# 153    177      M9R    Etobicoke      Martin Grove Gardens
# 154    176      M9R    Etobicoke         Kingsview Village
# 155    229      M9V    Etobicoke          Beaumond Heights
# 156    233      M9V    Etobicoke               Silverstone
# 157    230      M9V    Etobicoke                Humbergate
# 158    231      M9V    Etobicoke                 Jamestown
# 159    232      M9V    Etobicoke               Mount Olive
# 160    235      M9V    Etobicoke               Thistletown
# 161    228      M9V    Etobicoke            Albion Gardens
# 162    234      M9V    Etobicoke             South Steeles
#
# [163 rows x 4 columns]

# %%
# TABLE WITH single NEIGHBOURHOOD FOR SINGLE postocde
tab2 = data_table.loc[data_table.Postcode.isin(postcode_single),:].sort_values(by='Postcode').reset_index(drop=True)
tab2
# Out:
#     index Postcode           Borough  \
# 0      53      M1G       Scarborough
# 1      62      M1H       Scarborough
# 2      76      M1J       Scarborough
# 3     180      M1S       Scarborough
# 4     236      M1W       Scarborough
# 5     246      M1X       Scarborough
# 6      63      M2H        North York
# 7      94      M2K        North York
# 8     142      M2N        North York
# 9     154      M2P        North York
# 10    166      M2R        North York
# 11      3      M3A        North York
# 12     14      M3B        North York
# 13    112      M3L        North York
# 14    128      M3M        North York
# 15    143      M3N        North York
# 16      4      M4A        North York
# 17     33      M4C         East York
# 18     47      M4E      East Toronto
# 19     56      M4G         East York
# 20     67      M4H         East York
# 21     82      M4J         East York
# 22    129      M4M      East Toronto
# 23    144      M4N   Central Toronto
# 24    156      M4P   Central Toronto
# 25    168      M4R   Central Toronto
# 26    183      M4S   Central Toronto
# 27    239      M4W  Downtown Toronto
# 28    262      M4Y  Downtown Toronto
# 29      5      M5A  Downtown Toronto
# 30     34      M5C  Downtown Toronto
# 31     48      M5E  Downtown Toronto
# 32     57      M5G  Downtown Toronto
# 33    145      M5N   Central Toronto
# 34    240      M5W  Downtown Toronto
# 35     19      M6B        North York
# 36     35      M6C              York
# 37     49      M6E              York
# 38     58      M6G  Downtown Toronto
# 39      8      M7A  Downtown Toronto
# 40    174      M7R       Mississauga
# 41    265      M7Y      East Toronto
# 42     10      M9A         Etobicoke
# 43    122      M9L        North York
# 44    150      M9N              York
# 45    163      M9P         Etobicoke
# 46    245      M9W         Etobicoke
#
#                                         Neighbourhood
# 0                                              Woburn
# 1                                           Cedarbrae
# 2                                 Scarborough Village
# 3                                           Agincourt
# 4                                     L'Amoreaux West
# 5                                         Upper Rouge
# 6                                   Hillcrest Village
# 7                                     Bayview Village
# 8                                    Willowdale South
# 9                                     York Mills West
# 10                                    Willowdale West
# 11                                          Parkwoods
# 12                                    Don Mills North
# 13                                     Downsview West
# 14                                  Downsview Central
# 15                                Downsview Northwest
# 16                                   Victoria Village
# 17                                   Woodbine Heights
# 18                                        The Beaches
# 19                                            Leaside
# 20                                   Thorncliffe Park
# 21                                       East Toronto
# 22                                    Studio District
# 23                                      Lawrence Park
# 24                                   Davisville North
# 25                                 North Toronto West
# 26                                         Davisville
# 27                                           Rosedale
# 28                               Church and Wellesley
# 29                                       Harbourfront
# 30                                     St. James Town
# 31                                        Berczy Park
# 32                                 Central Bay Street
# 33                                           Roselawn
# 34                    Stn A PO Boxes 25 The Esplanade
# 35                                          Glencairn
# 36                                 Humewood-Cedarvale
# 37                                Caledonia-Fairbanks
# 38                                           Christie
# 39                                       Queen's Park
# 40              Canada Post Gateway Processing Centre
# 41  Business Reply Mail Processing Centre 969 Eastern
# 42                                   Islington Avenue
# 43                                      Humber Summit
# 44                                             Weston
# 45                                          Westmount
# 46                                          Northwest

# %%
#nEIGHBOUR LIST FROM TABLE 1
codes = []
boroughs = []
neighbours = []

for code in postcode_mult:
    
    table = tab1.loc[tab1.Postcode == code, :] # split 't1' to specific table by 'postcode'
    
    code = np.unique(table.Postcode) # extract unique 'postcode' in the column
    codes.append(code[0])
    
    borough = np.unique(table.Borough) # extract unique 'borough' in the column
    boroughs.append(borough[0])
    
    neighbour = table["Neighbourhood"].tolist() # extract all 'neighbourhood' & convert to list format
    neighbour = ', '.join(neighbour) # use .join() method to combine each 'neighbourhood' with ", "
    neighbours.append(neighbour)

# %%
# NEW DF FOR POSTCODE WITH MULTIPLE NEIGHBOURHOODS

table_new = pd.DataFrame({'Postcode': codes, 'Borough': boroughs, 'Neighbourhood': neighbours})
table_new.head()
# Out:
#   Postcode      Borough                                Neighbourhood
# 0      M1B  Scarborough                               Rouge, Malvern
# 1      M1C  Scarborough       Port Union, Rouge Hill, Highland Creek
# 2      M1E  Scarborough            Guildwood, West Hill, Morningside
# 3      M1K  Scarborough  East Birchmount Park, Ionview, Kennedy Park
# 4      M1L  Scarborough              Clairlea, Golden Mile, Oakridge

# %%
# CREATING NEW TABLE (TREATED) WITH SINGLE TABLE, WITH MULTIPLE NEIGHBOURHOODS ADDED AS SINGLE ROWS

new_data = pd.concat([table_new, tab2], axis=0).sort_values(by="Postcode").reset_index(drop=True)
new_data.drop("index", axis = 1, inplace = True)
new_data.shape
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   This is separate from the ipykernel package so we can avoid doing imports until
# (103, 3)

# %%
new_data.shape
# Out:
# (103, 3)

# %% [markdown]
#  ### PART 2 - getting the latitude and the longitude coordinates of each neighborhood

# %%
# importing libraries
import geopy
import geopandas

# %%
geo_lati = {}
geo_long = {}

geo = geopy.Nominatim(user_agent="Detector", timeout=20)

for z in np.unique(new_data.Borough):
    
    location = geo.geocode("{}, Toronto, Ontario".format(z))
    
    geo_lati[x] = location.latitude
    geo_long[x] = location.longitude

# %%
# latitude
geo_lati
# Out:
# {'Central Toronto': 43.6449033,
#  'Downtown Toronto': 43.6563221,
#  'East Toronto': 43.626243,
#  'East York': 43.699971000000005,
#  'Etobicoke': 43.671459150000004,
#  'Mississauga': 43.6597818,
#  'North York': 43.7543263,
#  'Scarborough': 43.773077,
#  'West Toronto': 43.6449033,
#  'York': 43.67910515}

# %%
# Longitude
geo_long
# Out:
# {'Central Toronto': -79.3818364,
#  'Downtown Toronto': -79.3809161,
#  'East Toronto': -79.396962,
#  'East York': -79.33251996261595,
#  'Etobicoke': -79.55249206611668,
#  'Mississauga': -79.64739965714713,
#  'North York': -79.44911696639593,
#  'Scarborough': -79.257774,
#  'West Toronto': -79.3818364,
#  'York': -79.49118414007154}

# %%
# Error; Hence going to use csv
geo = geopy.Nominatim(user_agent="Detector", timeout=50)

for x, y in zip(new_data.Postcode[0:5], new_data.Borough[0:5]):
    
    loc = geo.geocode("{}, {}, Toronto, Canada".format(x, y))
    print("{}, {}: latitude {}, longitude {}".format(x, y, loc.latitude, loc.longitude))
# Out:
# M1B, Scarborough: latitude 43.773077, longitude -79.257774
# M1C, Scarborough: latitude 43.773077, longitude -79.257774
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-74-35386dc008cc> in <module>()
#       5
#       6     loc = geo.geocode("{}, {}, Toronto, Canada".format(x, y))
# ----> 7     print("{}, {}: latitude {}, longitude {}".format(x, y, loc.latitude, loc.longitude))
#
# AttributeError: 'NoneType' object has no attribute 'latitude'

# %%
# using the data provided instead, geopy seems to be broken

geo_data = pd.read_csv("http://cocl.us/Geospatial_data")
geo_data.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
# merging to get lat and longitude

geo_df = geo_data.loc[geo_data["Postal Code"].isin(new_data.Postcode.values), :]
print(geo_df.shape)

geo_table = new_data.merge(geo_df, left_on="Postcode", right_on="Postal Code")
geo_table.head()
# Out:
# (103, 3)
#        Borough                           Neighbourhood Postcode Postal Code  \
# 0  Scarborough                          Rouge, Malvern      M1B         M1B
# 1  Scarborough  Port Union, Rouge Hill, Highland Creek      M1C         M1C
# 2  Scarborough       Guildwood, West Hill, Morningside      M1E         M1E
# 3  Scarborough                                  Woburn      M1G         M1G
# 4  Scarborough                               Cedarbrae      M1H         M1H
#
#     Latitude  Longitude
# 0  43.806686 -79.194353
# 1  43.784535 -79.160497
# 2  43.763573 -79.188711
# 3  43.770992 -79.216917
# 4  43.773136 -79.239476

# %%
geo_table = geo_table[["Postcode", "Borough", "Neighbourhood", "Latitude", "Longitude"]]
geo_table.head()
# Out:
#   Postcode      Borough                           Neighbourhood   Latitude  \
# 0      M1B  Scarborough                          Rouge, Malvern  43.806686
# 1      M1C  Scarborough  Port Union, Rouge Hill, Highland Creek  43.784535
# 2      M1E  Scarborough       Guildwood, West Hill, Morningside  43.763573
# 3      M1G  Scarborough                                  Woburn  43.770992
# 4      M1H  Scarborough                               Cedarbrae  43.773136
#
#    Longitude
# 0 -79.194353
# 1 -79.160497
# 2 -79.188711
# 3 -79.216917
# 4 -79.239476

# %%
geo_table.shape
# Out:
# (103, 5)

# %% [markdown]
# ### Part 3 - Explore and cluster the neighborhoods in Toronto

# %%
import folium
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe
import json # library to handle JSON files
address = 'Toronto, Ontario'

geolocator = geopy.Nominatim(user_agent="ny_explorer", timeout=30)
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto {}, {}.'.format(latitude, longitude))

# create map of Toronto using latitude and longitude values
map_of_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)


# add markers to map based on coordinates of postcode
for lat, lng, neighbourhood in zip(geo_table['Latitude'], geo_table['Longitude'], geo_table['Neighbourhood']):
    label = '{}'.format(neighbourhood)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='grey',
        fill=True,
        fill_color='#009fe3',
        fill_opacity=0.7,
        parse_html=False).add_to(map_of_toronto)  
    
map_of_toronto
# Out:
# The geograpical coordinate of Toronto 43.653963, -79.387207.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Foursquare ID
CLIENT_ID = "GPB2DWEOQ2QZ1D1DXQYB1IXWQT0YCXRJWR1OHQ5BCB1BTBBP" 
#Foursquare Secret
CLIENT_SECRET = "ILCEJ32YAXA3E5W3FB1WFAQ2RHXEFX2YW414DY4YQBUXJKGB"
# Foursquare API version
VERSION = "20161225"

# %%
LIMIT = 5
radius = 500

location_list = [] # list to store data from Foursquare API requests

for neighbourhood, latitude, longitude in zip(geo_table.Neighbourhood, geo_table.Latitude, geo_table.Longitude):
    
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude, 
    longitude, 
    radius, 
    LIMIT)
    
    data = requests.get(url).json()
    
    # use len() to check if any data within "items" (len = 0 if nothing)
    length = len(data['response']['groups'][0]['items'])
    if length == 0:
        continue # skip the row if nothing is found
    else:
        venue = data['response']['groups'][0]['items'][0]['venue']
        
        # extract info within 'venue'
        name = venue['name']
        lat = venue['location']['lat']
        lon = venue['location']['lng']
        cat = venue['categories'][0]['name']
        
        location_list.append([(neighbourhood, latitude, longitude, name, lat, lon, cat)])

# %%
dat = pd.DataFrame(x for row in location_list for x in row)
dat.columns = ['Neighbourhood','N_Latitude','N_Longitude','Venue','V_Latitude','V_Longitude','category']
dat.head()
# Out:
#                             Neighbourhood  N_Latitude  N_Longitude  \
# 0                          Rouge, Malvern   43.806686   -79.194353
# 1  Port Union, Rouge Hill, Highland Creek   43.784535   -79.160497
# 2       Guildwood, West Hill, Morningside   43.763573   -79.188711
# 3                                  Woburn   43.770992   -79.216917
# 4                               Cedarbrae   43.773136   -79.239476
#
#                    Venue  V_Latitude  V_Longitude              category
# 0                Wendy's   43.807448   -79.199056  Fast Food Restaurant
# 1  Royal Canadian Legion   43.782533   -79.163085                   Bar
# 2      G & G Electronics   43.765309   -79.191537     Electronics Store
# 3              Starbucks   43.770037   -79.221156           Coffee Shop
# 4    Federick Restaurant   43.774697   -79.241142      Hakka Restaurant

# %%
# create map of Toronto using latitude and longitude values
map_dat = folium.Map(location=[latitude, longitude], zoom_start=10)


# add markers to map based on coordinates of postcode
for lat, lng, neighbourhood in zip(dat['V_Latitude'], dat['V_Longitude'], dat['Venue']):
    label = '{}'.format(neighbourhood)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='grey',
        fill=True,
        fill_color='#009fe3',
        fill_opacity=0.7,
        parse_html=False).add_to(map_dat)  
    
map_dat
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## K- means clustering based on lat and long of neighbourhood

# %%
# setting up packages for clustering
import numpy as np
import pandas as pdb
from matplotlib import pyplot as plt
from sklearn.datasets.samples_generator import make_blobs
from sklearn.cluster import KMeans

import matplotlib.cm as cm
import matplotlib.colors as colors
import folium # map rendering library

# %%
geo_table
# Out:
#      Cluster Labels Postcode           Borough  \
# 0                 0      M1B       Scarborough
# 1                 0      M1C       Scarborough
# 2                 0      M1E       Scarborough
# 3                 0      M1G       Scarborough
# 4                 0      M1H       Scarborough
# 5                 0      M1J       Scarborough
# 6                 0      M1K       Scarborough
# 7                 2      M1L       Scarborough
# 8                 0      M1M       Scarborough
# 9                 2      M1N       Scarborough
# 10                0      M1P       Scarborough
# 11                0      M1R       Scarborough
# 12                0      M1S       Scarborough
# 13                0      M1T       Scarborough
# 14                0      M1V       Scarborough
# 15                0      M1W       Scarborough
# 16                0      M1X       Scarborough
# 17                4      M2H        North York
# 18                4      M2J        North York
# 19                4      M2K        North York
# 20                4      M2L        North York
# 21                4      M2M        North York
# 22                4      M2N        North York
# 23                4      M2P        North York
# 24                4      M2R        North York
# 25                2      M3A        North York
# 26                2      M3B        North York
# 27                2      M3C        North York
# 28                4      M3H        North York
# 29                4      M3J        North York
# ..              ...      ...               ...
# 73                3      M6C              York
# 74                3      M6E              York
# 75                3      M6G  Downtown Toronto
# 76                3      M6H      West Toronto
# 77                3      M6J      West Toronto
# 78                3      M6K      West Toronto
# 79                1      M6L        North York
# 80                1      M6M              York
# 81                1      M6N              York
# 82                3      M6P      West Toronto
# 83                3      M6R      West Toronto
# 84                1      M6S      West Toronto
# 85                3      M7A  Downtown Toronto
# 86                1      M7R       Mississauga
# 87                2      M7Y      East Toronto
# 88                1      M8V         Etobicoke
# 89                1      M8W         Etobicoke
# 90                1      M8X         Etobicoke
# 91                1      M8Y         Etobicoke
# 92                1      M8Z         Etobicoke
# 93                1      M9A         Etobicoke
# 94                1      M9B         Etobicoke
# 95                1      M9C         Etobicoke
# 96                1      M9L        North York
# 97                1      M9M        North York
# 98                1      M9N              York
# 99                1      M9P         Etobicoke
# 100               1      M9R         Etobicoke
# 101               1      M9V         Etobicoke
# 102               1      M9W         Etobicoke
#
#                                          Neighbourhood   Latitude  Longitude
# 0                                       Rouge, Malvern  43.806686 -79.194353
# 1               Port Union, Rouge Hill, Highland Creek  43.784535 -79.160497
# 2                    Guildwood, West Hill, Morningside  43.763573 -79.188711
# 3                                               Woburn  43.770992 -79.216917
# 4                                            Cedarbrae  43.773136 -79.239476
# 5                                  Scarborough Village  43.744734 -79.239476
# 6          East Birchmount Park, Ionview, Kennedy Park  43.727929 -79.262029
# 7                      Clairlea, Golden Mile, Oakridge  43.711112 -79.284577
# 8      Scarborough Village West, Cliffside, Cliffcrest  43.716316 -79.239476
# 9                          Cliffside West, Birch Cliff  43.692657 -79.264848
# 10   Dorset Park, Scarborough Town Centre, Wexford ...  43.757410 -79.273304
# 11                                   Wexford, Maryvale  43.750072 -79.295849
# 12                                           Agincourt  43.794200 -79.262029
# 13             Tam O'Shanter, Sullivan, Clarks Corners  43.781638 -79.304302
# 14   Agincourt North, Steeles East, L'Amoreaux East...  43.815252 -79.284577
# 15                                     L'Amoreaux West  43.799525 -79.318389
# 16                                         Upper Rouge  43.836125 -79.205636
# 17                                   Hillcrest Village  43.803762 -79.363452
# 18                        Henry Farm, Fairview, Oriole  43.778517 -79.346556
# 19                                     Bayview Village  43.786947 -79.385975
# 20                            York Mills, Silver Hills  43.757490 -79.374714
# 21                             Newtonbrook, Willowdale  43.789053 -79.408493
# 22                                    Willowdale South  43.770120 -79.408493
# 23                                     York Mills West  43.752758 -79.400049
# 24                                     Willowdale West  43.782736 -79.442259
# 25                                           Parkwoods  43.753259 -79.329656
# 26                                     Don Mills North  43.745906 -79.352188
# 27                    Flemingdon Park, Don Mills South  43.725900 -79.340923
# 28     Wilson Heights, Downsview North, Bathurst Manor  43.754328 -79.442259
# 29                     Northwood Park, York University  43.767980 -79.487262
# ..                                                 ...        ...        ...
# 73                                  Humewood-Cedarvale  43.693781 -79.428191
# 74                                 Caledonia-Fairbanks  43.689026 -79.453512
# 75                                            Christie  43.669542 -79.422564
# 76                        Dovercourt Village, Dufferin  43.669005 -79.442259
# 77                            Little Portugal, Trinity  43.647927 -79.419750
# 78        Brockton, Parkdale Village, Exhibition Place  43.636847 -79.428191
# 79                  North Park, Downsview, Upwood Park  43.713756 -79.490074
# 80      Silverthorn, Mount Dennis, Keelesdale, Del Ray  43.691116 -79.476013
# 81                       The Junction North, Runnymede  43.673185 -79.487262
# 82                       High Park, The Junction South  43.661608 -79.464763
# 83                              Parkdale, Roncesvalles  43.648960 -79.456325
# 84                                  Swansea, Runnymede  43.651571 -79.484450
# 85                                        Queen's Park  43.662301 -79.389494
# 86               Canada Post Gateway Processing Centre  43.636966 -79.615819
# 87   Business Reply Mail Processing Centre 969 Eastern  43.662744 -79.321558
# 88        New Toronto, Mimico South, Humber Bay Shores  43.605647 -79.501321
# 89                              Long Branch, Alderwood  43.602414 -79.543484
# 90       Old Mill North, Montgomery Road, The Kingsway  43.653654 -79.506944
# 91   Mimico NE, Kingsway Park South East, Old Mill ...  43.636258 -79.498509
# 92   The Queensway West, Kingsway Park South West, ...  43.628841 -79.520999
# 93                                    Islington Avenue  43.667856 -79.532242
# 94   Princess Gardens, Martin Grove, Islington, Clo...  43.650943 -79.554724
# 95   Old Burnhamthorpe, Markland Wood, Eringate, Bl...  43.643515 -79.577201
# 96                                       Humber Summit  43.756303 -79.565963
# 97                                    Emery, Humberlea  43.724766 -79.532242
# 98                                              Weston  43.706876 -79.518188
# 99                                           Westmount  43.696319 -79.532242
# 100  St. Phillips, Richview Gardens, Martin Grove G...  43.688905 -79.554724
# 101  Beaumond Heights, Silverstone, Humbergate, Jam...  43.739416 -79.588437
# 102                                          Northwest  43.706748 -79.594054
#
# [103 rows x 6 columns]

# %%
# dataframe for clustering

# set number of clusters
kclusters = 5

toronto_grouped_clustering = geo_table.drop(["Postcode","Borough","Neighbourhood"],axis= 1)
#toronto_grouped_clustering

# # run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# # check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([0, 0, 0, 0, 0, 0, 0, 2, 0, 2])

# %%
geo_table.insert(0, 'Cluster Labels', kmeans.labels_)


geo_table.head()
# Out:
#    Cluster Labels Postcode      Borough  \
# 0               0      M1B  Scarborough
# 1               0      M1C  Scarborough
# 2               0      M1E  Scarborough
# 3               0      M1G  Scarborough
# 4               0      M1H  Scarborough
#
#                             Neighbourhood   Latitude  Longitude
# 0                          Rouge, Malvern  43.806686 -79.194353
# 1  Port Union, Rouge Hill, Highland Creek  43.784535 -79.160497
# 2       Guildwood, West Hill, Morningside  43.763573 -79.188711
# 3                                  Woburn  43.770992 -79.216917
# 4                               Cedarbrae  43.773136 -79.239476

# %%
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# %%
# add clusters to the map
markers_colors = []
for lat, lon, poi, cluster in zip(geo_table['Latitude'], geo_table['Longitude'], geo_table['Borough'], geo_table['Cluster Labels']):
    
    label = folium.Popup(
        str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
